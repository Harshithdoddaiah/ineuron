# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_csv('abcd.csv')

# %%
df.drop(columns=df.columns[0], axis=1, inplace=True)

# %%
df
# Out:
#             id                                               user  \
# 0   1439509584  {'login': 'topper-123', 'id': 26364415, 'node_...
# 1   1439500185  {'login': 'topper-123', 'id': 26364415, 'node_...
# 2   1439409786  {'login': 'topper-123', 'id': 26364415, 'node_...
# 3   1439252530  {'login': 'Samreay', 'id': 6748505, 'node_id':...
# 4   1439212769  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 5   1439178664  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 6   1438989277  {'login': 'Zaijab', 'id': 40334752, 'node_id':...
# 7   1438695744  {'login': 'rwijtvliet', 'id': 4106013, 'node_i...
# 8   1438689491  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 9   1438664984  {'login': 'rwijtvliet', 'id': 4106013, 'node_i...
# 10  1437669869  {'login': 'WindSoilder', 'id': 22256154, 'node...
# 11  1437564458  {'login': 'topper-123', 'id': 26364415, 'node_...
# 12  1437421997  {'login': 'lukemanley', 'id': 8519523, 'node_i...
# ...

# %%
df1=df['user'].str.split(',', expand=True)

# %%
df1
# Out:
#                                 0                 1   \
# 0           {'login': 'topper-123'    'id': 26364415
# 1           {'login': 'topper-123'    'id': 26364415
# 2           {'login': 'topper-123'    'id': 26364415
# 3              {'login': 'Samreay'     'id': 6748505
# 4            {'login': 'mroeschke'    'id': 10647082
# 5            {'login': 'mroeschke'    'id': 10647082
# 6               {'login': 'Zaijab'    'id': 40334752
# 7           {'login': 'rwijtvliet'     'id': 4106013
# 8         {'login': 'jbrockmendel'     'id': 8078968
# 9           {'login': 'rwijtvliet'     'id': 4106013
# 10         {'login': 'WindSoilder'    'id': 22256154
# 11          {'login': 'topper-123'    'id': 26364415
# 12          {'login': 'lukemanley'     'id': 8519523
# 13            {'login': 'Th3nn3ss'    'id': 25160953
# 14          {'login': 'ramvikrams'   'id': 106332857
# 15            {'login': 'Th3nn3ss'    'id': 25160953
# 16               {'login': 'csala'     'id': 6129283
# ...

# %%
#df1[0]=df1[0].str.replace("{'login':", '')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_10504\1613896110.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1[0]=df1[0].str.replace("{'login':", '')

# %%
df1=df1.set_axis(['login', 'id', 'node_id', 'avatar_url', 'gravatar_id', 'url', 'html_url', 'followers_url', 'following_url', 'gists_url', 'starred_url', 'subscriptions_url', 'organizations_url', 'repos_url', 'events_url', 'received_events_url', 'type', 'site_admin'], axis=1)

# %%
df1
# Out:
#                              login                id  \
# 0           {'login': 'topper-123'    'id': 26364415
# 1           {'login': 'topper-123'    'id': 26364415
# 2           {'login': 'topper-123'    'id': 26364415
# 3              {'login': 'Samreay'     'id': 6748505
# 4            {'login': 'mroeschke'    'id': 10647082
# 5            {'login': 'mroeschke'    'id': 10647082
# 6               {'login': 'Zaijab'    'id': 40334752
# 7           {'login': 'rwijtvliet'     'id': 4106013
# 8         {'login': 'jbrockmendel'     'id': 8078968
# 9           {'login': 'rwijtvliet'     'id': 4106013
# 10         {'login': 'WindSoilder'    'id': 22256154
# 11          {'login': 'topper-123'    'id': 26364415
# 12          {'login': 'lukemanley'     'id': 8519523
# 13            {'login': 'Th3nn3ss'    'id': 25160953
# 14          {'login': 'ramvikrams'   'id': 106332857
# 15            {'login': 'Th3nn3ss'    'id': 25160953
# 16               {'login': 'csala'     'id': 6129283
# ...

# %%
df1=df1.replace(regex={"{'login':": '', "id':": '', "'node_":'',"'avatar_url':":'',"'gravatar_":'', "'url':":'', "'html_url':":'',"'followers_url':":'',"'following_url':":'',"'gists_url':":'',"'starred_url':":'',"'subscriptions_url':":'',"'organizations_url':":'',"'repos_url':":'',"'events_url':":'',"'received_events_url':":'',"'type':":'',"'site_admin':":''})

# %%
df1
# Out:
#                     login            id                   node_id  \
# 0            'topper-123'    ' 26364415    'MDQ6VXNlcjI2MzY0NDE1'
# 1            'topper-123'    ' 26364415    'MDQ6VXNlcjI2MzY0NDE1'
# 2            'topper-123'    ' 26364415    'MDQ6VXNlcjI2MzY0NDE1'
# 3               'Samreay'     ' 6748505    'MDQ6VXNlcjY3NDg1MDU='
# 4             'mroeschke'    ' 10647082    'MDQ6VXNlcjEwNjQ3MDgy'
# 5             'mroeschke'    ' 10647082    'MDQ6VXNlcjEwNjQ3MDgy'
# 6                'Zaijab'    ' 40334752    'MDQ6VXNlcjQwMzM0NzUy'
# 7            'rwijtvliet'     ' 4106013    'MDQ6VXNlcjQxMDYwMTM='
# 8          'jbrockmendel'     ' 8078968    'MDQ6VXNlcjgwNzg5Njg='
# 9            'rwijtvliet'     ' 4106013    'MDQ6VXNlcjQxMDYwMTM='
# 10          'WindSoilder'    ' 22256154    'MDQ6VXNlcjIyMjU2MTU0'
# 11           'topper-123'    ' 26364415    'MDQ6VXNlcjI2MzY0NDE1'
# 12           'lukemanley'     ' 8519523    'MDQ6VXNlcjg1MTk1MjM='
# ...

# %%
df1=df1.replace(regex=["'", '}'], value='')

# %%
df1
# Out:
#                   login           id                 node_id  \
# 0            topper-123     26364415    MDQ6VXNlcjI2MzY0NDE1
# 1            topper-123     26364415    MDQ6VXNlcjI2MzY0NDE1
# 2            topper-123     26364415    MDQ6VXNlcjI2MzY0NDE1
# 3               Samreay      6748505    MDQ6VXNlcjY3NDg1MDU=
# 4             mroeschke     10647082    MDQ6VXNlcjEwNjQ3MDgy
# 5             mroeschke     10647082    MDQ6VXNlcjEwNjQ3MDgy
# 6                Zaijab     40334752    MDQ6VXNlcjQwMzM0NzUy
# 7            rwijtvliet      4106013    MDQ6VXNlcjQxMDYwMTM=
# 8          jbrockmendel      8078968    MDQ6VXNlcjgwNzg5Njg=
# 9            rwijtvliet      4106013    MDQ6VXNlcjQxMDYwMTM=
# 10          WindSoilder     22256154    MDQ6VXNlcjIyMjU2MTU0
# 11           topper-123     26364415    MDQ6VXNlcjI2MzY0NDE1
# 12           lukemanley      8519523    MDQ6VXNlcjg1MTk1MjM=
# 13             Th3nn3ss     25160953    MDQ6VXNlcjI1MTYwOTUz
# ...

# %%
df.drop(['user'], axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8708\2087129275.py in <module>
# ----> 1 df.drop(['user'], axis=1,inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df
# Out:
#             id                                                url  \
# 0   1439509584  https://api.github.com/repos/pandas-dev/pandas...
# 1   1439500185  https://api.github.com/repos/pandas-dev/pandas...
# 2   1439409786  https://api.github.com/repos/pandas-dev/pandas...
# 3   1439252530  https://api.github.com/repos/pandas-dev/pandas...
# 4   1439212769  https://api.github.com/repos/pandas-dev/pandas...
# 5   1439178664  https://api.github.com/repos/pandas-dev/pandas...
# 6   1438989277  https://api.github.com/repos/pandas-dev/pandas...
# 7   1438695744  https://api.github.com/repos/pandas-dev/pandas...
# 8   1438689491  https://api.github.com/repos/pandas-dev/pandas...
# 9   1438664984  https://api.github.com/repos/pandas-dev/pandas...
# 10  1437669869  https://api.github.com/repos/pandas-dev/pandas...
# 11  1437564458  https://api.github.com/repos/pandas-dev/pandas...
# 12  1437421997  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df1
# Out:
#                   login           id                 node_id  \
# 0            topper-123     26364415    MDQ6VXNlcjI2MzY0NDE1
# 1            topper-123     26364415    MDQ6VXNlcjI2MzY0NDE1
# 2            topper-123     26364415    MDQ6VXNlcjI2MzY0NDE1
# 3               Samreay      6748505    MDQ6VXNlcjY3NDg1MDU=
# 4             mroeschke     10647082    MDQ6VXNlcjEwNjQ3MDgy
# 5             mroeschke     10647082    MDQ6VXNlcjEwNjQ3MDgy
# 6                Zaijab     40334752    MDQ6VXNlcjQwMzM0NzUy
# 7            rwijtvliet      4106013    MDQ6VXNlcjQxMDYwMTM=
# 8          jbrockmendel      8078968    MDQ6VXNlcjgwNzg5Njg=
# 9            rwijtvliet      4106013    MDQ6VXNlcjQxMDYwMTM=
# 10          WindSoilder     22256154    MDQ6VXNlcjIyMjU2MTU0
# 11           topper-123     26364415    MDQ6VXNlcjI2MzY0NDE1
# 12           lukemanley      8519523    MDQ6VXNlcjg1MTk1MjM=
# 13             Th3nn3ss     25160953    MDQ6VXNlcjI1MTYwOTUz
# ...

# %%
result = pd.concat([df, df1], axis=1, join='inner')
display(result)
# Out:
#             id                                                url  \
# 0   1439509584  https://api.github.com/repos/pandas-dev/pandas...
# 1   1439500185  https://api.github.com/repos/pandas-dev/pandas...
# 2   1439409786  https://api.github.com/repos/pandas-dev/pandas...
# 3   1439252530  https://api.github.com/repos/pandas-dev/pandas...
# 4   1439212769  https://api.github.com/repos/pandas-dev/pandas...
# 5   1439178664  https://api.github.com/repos/pandas-dev/pandas...
# 6   1438989277  https://api.github.com/repos/pandas-dev/pandas...
# 7   1438695744  https://api.github.com/repos/pandas-dev/pandas...
# 8   1438689491  https://api.github.com/repos/pandas-dev/pandas...
# 9   1438664984  https://api.github.com/repos/pandas-dev/pandas...
# 10  1437669869  https://api.github.com/repos/pandas-dev/pandas...
# 11  1437564458  https://api.github.com/repos/pandas-dev/pandas...
# 12  1437421997  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
result.to_csv('hemu_task.csv', index=False)
