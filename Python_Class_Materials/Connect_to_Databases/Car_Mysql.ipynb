# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host='localhost',user='system',passwd="system")

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('hari',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %%
cursor.execute("create database cardataset")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21844/2144735912.py in <module>
# ----> 1 cursor.execute("create database cardataset")
#
# ~\AppData\Roaming\Python\Python39\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     570
#     571         try:
# --> 572             self._handle_result(self._connection.cmd_query(stmt))
#     573         except errors.InterfaceError:
#     574             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\AppData\Roaming\Python\Python39\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     918         query = bytes(packet)
#     919         try:
# --> 920             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     921         except errors.ProgrammingError as err:
# ...

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('hari',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %%
cursor.execute("drop table cardataset.car")

# %%
cursor.execute("create table cardataset.car(buying VARCHAR(20), maint VARCHAR(20), doors VARCHAR(10), persons VARCHAR(10), lug_boot VARCHAR(10), safety VARCHAR(10), class VARCHAR(10))")

# %%
cursor.execute('use cardataset')

# %% [raw]
# cursor.execute('show tables')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('car',)]

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 8450-1D05
#
#  Directory of C:\Users\Harshith D\ineuron
#
# 26-02-2022  11:43 AM    <DIR>          .
# 26-02-2022  11:43 AM    <DIR>          ..
# 26-02-2022  10:51 AM    <DIR>          .ipynb_checkpoints
# 19-08-2021  07:41 AM               151 BullseyeCoverageError.txt
# 16-12-2021  10:48 AM             1,337 calendar.ipynb
# 23-02-2022  08:53 AM            51,867 car.data
# 26-02-2022  10:39 AM             3,097 car.names
# 26-02-2022  11:43 AM            63,385 Car_Mysql.ipynb
# 10-12-2021  11:56 AM            12,878 Day 1.ipynb
# 11-12-2021  09:34 AM            28,606 Day2.ipynb
# 28-01-2022  09:01 PM            16,103 exception handling.ipynb
# 16-01-2022  09:52 AM            17,536 function.ipynb
# 26-01-2022  12:35 PM            25,306 function2.ipynb
# 08-01-2022  11:44 AM            24,316 if, for-else,while.ipynb
# 28-01-2022  08:28 AM           214,133 iterable,iterator,generator,filesystem.ipynb
# ...

# %%
file = open("car.data","r")

# %%
file.read()
# Out:
# 'vhigh,vhigh,2,2,small,low,unacc\nvhigh,vhigh,2,2,small,med,unacc\nvhigh,vhigh,2,2,small,high,unacc\nvhigh,vhigh,2,2,med,low,unacc\nvhigh,vhigh,2,2,med,med,unacc\nvhigh,vhigh,2,2,med,high,unacc\nvhigh,vhigh,2,2,big,low,unacc\nvhigh,vhigh,2,2,big,med,unacc\nvhigh,vhigh,2,2,big,high,unacc\nvhigh,vhigh,2,4,small,low,unacc\nvhigh,vhigh,2,4,small,med,unacc\nvhigh,vhigh,2,4,small,high,unacc\nvhigh,vhigh,2,4,med,low,unacc\nvhigh,vhigh,2,4,med,med,unacc\nvhigh,vhigh,2,4,med,high,unacc\nvhigh,vhigh,2,4,big,low,unacc\nvhigh,vhigh,2,4,big,med,unacc\nvhigh,vhigh,2,4,big,high,unacc\nvhigh,vhigh,2,more,small,low,unacc\nvhigh,vhigh,2,more,small,med,unacc\nvhigh,vhigh,2,more,small,high,unacc\nvhigh,vhigh,2,more,med,low,unacc\nvhigh,vhigh,2,more,med,med,unacc\nvhigh,vhigh,2,more,med,high,unacc\nvhigh,vhigh,2,more,big,low,unacc\nvhigh,vhigh,2,more,big,med,unacc\nvhigh,vhigh,2,more,big,high,unacc\nvhigh,vhigh,3,2,small,low,unacc\nvhigh,vhigh,3,2,small,med,unacc\nvhigh,vhigh,3,2,small,high,unacc\nvhigh,
# ...

# %%
import csv
with open("car.data","r") as f:
    car_data=csv.reader(f,delimiter='\n')
    for i in car_data:
        print(i)
# Out:
# ['vhigh,vhigh,2,2,small,low,unacc']
# ['vhigh,vhigh,2,2,small,med,unacc']
# ['vhigh,vhigh,2,2,small,high,unacc']
# ['vhigh,vhigh,2,2,med,low,unacc']
# ['vhigh,vhigh,2,2,med,med,unacc']
# ['vhigh,vhigh,2,2,med,high,unacc']
# ['vhigh,vhigh,2,2,big,low,unacc']
# ['vhigh,vhigh,2,2,big,med,unacc']
# ['vhigh,vhigh,2,2,big,high,unacc']
# ['vhigh,vhigh,2,4,small,low,unacc']
# ['vhigh,vhigh,2,4,small,med,unacc']
# ['vhigh,vhigh,2,4,small,high,unacc']
# ['vhigh,vhigh,2,4,med,low,unacc']
# ['vhigh,vhigh,2,4,med,med,unacc']
# ['vhigh,vhigh,2,4,med,high,unacc']
# ['vhigh,vhigh,2,4,big,low,unacc']
# ['vhigh,vhigh,2,4,big,med,unacc']
# ['vhigh,vhigh,2,4,big,high,unacc']
# ['vhigh,vhigh,2,more,small,low,unacc']
# ['vhigh,vhigh,2,more,small,med,unacc']
# ['vhigh,vhigh,2,more,small,high,unacc']
# ['vhigh,vhigh,2,more,med,low,unacc']
# ['vhigh,vhigh,2,more,med,med,unacc']
# ['vhigh,vhigh,2,more,med,high,unacc']
# ['vhigh,vhigh,2,more,big,low,unacc']
# ['vhigh,vhigh,2,more,big,med,unacc']
# ...

# %%
import csv
with open("car.data","r") as f:
    car_data=csv.reader(f)
    for i in car_data:
        print(i)
        print(f'insert into cardataset.car (buying, maint, doors, persons, lug_boot, safety, class) values (%s,%s,%s,%s,%s,%s,%s)',i)
        cursor.execute(f'insert into cardataset.car (buying, maint, doors, persons, lug_boot, safety, class) values (%s,%s,%s,%s,%s,%s,%s)',i)
mydb.commit()
# Out:
# ['vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc']
# insert into cardataset.car (buying, maint, doors, persons, lug_boot, safety, class) values (%s,%s,%s,%s,%s,%s,%s) ['vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc']
# insert into cardataset.car (buying, maint, doors, persons, lug_boot, safety, class) values (%s,%s,%s,%s,%s,%s,%s) ['vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc']
# insert into cardataset.car (buying, maint, doors, persons, lug_boot, safety, class) values (%s,%s,%s,%s,%s,%s,%s) ['vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc']
# insert into cardataset.car (buying, maint, doors, persons, lug_boot, safety, class) values (%s,%s,%s,%s,%s,%s,%s) ['vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc']
# ...

# %%
cursor.execute("select * from car")

# %%
cursor.execute("select buying,count(*) from cardataset.car group by buying")

# %%
cursor.fetchall()
# Out:
# [('vhigh', 432), ('high', 432), ('med', 432), ('low', 432)]

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute('select * from car where doors=4')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute("update cardataset.car set doors='8' where doors='2'")

# %%
mydb.commit()
