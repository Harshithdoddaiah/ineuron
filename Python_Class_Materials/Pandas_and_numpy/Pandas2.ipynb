# %%
import pandas as pd

# %%
df=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df1=df[0]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[["Age","GS"]]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv("NBA.csv",index=False)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 8450-1D05
#
#  Directory of C:\Users\Harshith D\ineuron
#
# 15-03-2022  01:30 PM    <DIR>          .
# 15-03-2022  01:30 PM    <DIR>          ..
# 13-03-2022  01:31 PM    <DIR>          .ipynb_checkpoints
# 28-02-2022  08:05 PM    <DIR>          19.3 MongoDB
# 13-03-2022  11:23 AM             1,173 addresses.csv
# 19-08-2021  07:41 AM               151 BullseyeCoverageError.txt
# 16-12-2021  10:48 AM             1,337 calendar.ipynb
# 23-02-2022  08:53 AM            51,867 car.data
# 26-02-2022  10:39 AM             3,097 car.names
# 27-02-2022  11:35 AM           659,601 Car_Mysql.ipynb
# 12-03-2022  04:17 PM             3,724 Cassandra.ipynb
# 13-03-2022  11:23 AM             1,589 contacts.csv
# 13-03-2022  07:51 PM             5,658 cricket.csv
# 10-12-2021  11:56 AM            12,878 Day 1.ipynb
# 11-12-2021  09:34 AM            28,606 Day2.ipynb
# 13-03-2022  11:01 AM               307 example_test.csv
# 13-03-2022  11:54 AM               307 example_test1.csv
# 13-03-2022  11:50 AM               307 example_test1.csv.bak
# 28-01-2022  09:01 PM            16,103 exception handling.ipynb
# 16-01-2022  09:52 AM            17,536 function.ipynb
# 26-01-2022  12:35 PM            25,306 function2.ipynb
# 13-03-2022  11:23 AM               277 holiday_schedules.csv
# 08-01-2022  11:44 AM            24,316 if, for-else,while.ipynb
# 05-03-2022  03:25 PM             8,192 ineuron.db
# 28-01-2022  08:28 AM           214,133 iterable,iterator,generator,filesystem.ipynb
# 05-03-2022  04:00 PM            12,288 joindb.db
# 05-03-2022  04:10 PM             8,720 joindb.db-journal
# 13-03-2022  11:23 AM            18,015 locations.csv
# 28-01-2022  10:15 PM             5,090 logging.ipynb
# 13-03-2022  12:22 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 13-03-2022  12:22 PM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 13-03-2022  12:22 PM            24,471 LUSID Excel - Manage instruments with economic definitions.xlsx
# 13-03-2022  12:22 PM            84,319 LUSID Excel - Manage Orders.xlsx
# 13-03-2022  12:22 PM           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 13-03-2022  12:22 PM           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 13-03-2022  12:22 PM           136,632 LUSID Excel - Setting up your market data.xlsx
# 13-03-2022  11:23 AM             1,610 mail_addresses.csv
# 30-01-2022  11:15 AM            19,241 Modules, packages.ipynb
# 01-03-2022  12:25 PM             8,364 Mongodb_1.ipynb
# 01-03-2022  11:44 AM             3,280 Mongodb_1_Sunny.ipynb
# 01-02-2022  10:28 AM               657 mydict.py
# 29-01-2022  01:18 PM               228 mymodule.py
# 15-03-2022  01:32 PM            78,960 NBA.csv
# 01-02-2022  10:29 AM            17,072 oops.ipynb
# 04-02-2022  04:20 PM            19,886 oops2.ipynb
# 08-02-2022  08:48 AM             5,978 oops3.ipynb
# 13-03-2022  11:23 AM             2,281 organizations.csv
# 13-03-2022  12:40 PM           259,278 Pandas1.ipynb
# 15-03-2022  01:30 PM             9,446 Pandas2.ipynb
# 05-03-2022  03:23 PM             8,192 person.db
# 13-03-2022  11:23 AM             2,092 phones.csv
# 26-12-2021  10:19 AM                15 pillamma.txt
# 13-03-2022  11:23 AM                60 programs.csv
# 10-02-2022  08:40 AM           143,693 Python_MYSql1.ipynb
# 23-02-2022  08:44 AM           189,543 Python_MYSql2.ipynb
# 13-03-2022  11:23 AM               350 regular_schedules.csv
# 08-01-2022  02:42 PM             6,645 reverse, palindrome.ipynb
# 13-03-2022  11:23 AM            19,128 services.csv
# 12-03-2022  02:56 PM            42,432 SQLLite.ipynb
# 16-01-2022  01:05 PM             7,542 Task.ipynb
# 13-03-2022  11:23 AM            14,618 taxonomy.csv
# 28-01-2022  09:26 PM               591 teat.log
# 29-01-2022  12:54 PM               249 test.py
# 03-02-2022  08:07 AM                 7 test.txt
# 29-01-2022  12:15 PM                 0 test1.py
# 28-01-2022  07:14 PM                22 test1.txt
# 28-01-2022  10:02 PM             3,970 test2.log
# 27-01-2022  10:01 PM                25 test2.txt
# 28-01-2022  10:15 PM               621 test3.log
# 28-01-2022  07:27 PM                 0 test4.txt
# 01-02-2022  07:21 AM            16,890 Tuple,set,dict.ipynb
# 01-02-2022  07:17 PM             2,255 Untitled.ipynb
#               68 File(s)      2,896,048 bytes
#                4 Dir(s)  285,918,478,336 bytes free

# %%
df=pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(df)
# Out:
# 3

# %%
df[0]
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
# 95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# 1    0  0  0   0   0
# 2    -  -  -   -   -
# 3    0  0  0  14   1
# 4    -  -  -   -   -
# ..  .. .. ..  ..  ..
# 92   0  0  0   0   0
# 93   0  0  3   4   3
# 94   0  4  1  32  20
# 95   0  0  0   0   0
# 96   0  8  1  77  74
#
# [97 rows x 15 columns]

# %%
df[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
df[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Sri Lanka at Dharamsala, 3rd T20I, Feb...
# 2  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
# 3  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...

# %%
df[0].to_csv("cricket.csv",index=False)

# %%
d="""{"name":"Harshith D",
"emailid":"harshith@gmail.com",
"tech":["ML","DL","CV"],
"plateform" : ["techneuron","kidsnueron","inueron"]
}"""

# %%
import json

# %%
result=json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#          name             emailid tech   plateform
# 0  Harshith D  harshith@gmail.com   ML  techneuron
# 1  Harshith D  harshith@gmail.com   DL  kidsnueron
# 2  Harshith D  harshith@gmail.com   CV     inueron

# %%
result['name']
# Out:
# 'Harshith D'

# %%
pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# tcuTemperatureAverage              D
# coolantMin                         D
# coolantMax                         D
# coolantAverage                     D
# packetStartLocal                   D
# tripStartLocal                     D
# milIndicator                       D
# monitorsNotReady                   D
# imei                               D
# gatewayTs                          D
# diagnosticTroubleCodeData          D
# diagnosticPidData                  D
# iwrapVer                           D
# sourceSystem                       D
# configVer                          D
# oemName                            D
# unitType                           D
# cpVer                              D
# igpsVer                            D
# messageType                        D
# pomVer                             D
# headerVer                          D
# timestamp                          D
# deviceType                         D
# visorVer                           D
# transactionId                      D
# deviceSerialNo                     D
# subOrganization                    D
# organization                       D
# operation                          D
#
#                                                                         data  \
# checkEngineLightFlag                                                       F
# batteryVoltageStableTime                                                   0
# batteryVoltageStable                                                       0
# batteryVoltageOff                                                      12.42
# batteryCrankParamTN                                                    -0.08
# batteryCrankParamVN                                                     0.00
# batteryCrankParamTP                                                    -0.08
# batteryCrankParamVP                                                     0.00
# batteryCrankParamTT                                                 -0.00008
# batteryCrankParamV0                                                     0.00
# batteryVoltageMaxOn                                                    13.05
# batteryVoltageMinOn                                                    12.97
# batteryVoltageMaxOff                                                   12.46
# batteryVoltageMinOff                                                   12.36
# batteryVoltageOnAverage                                                13.02
# engineLoadMax                                                             84
# engineLoadAverage                                                      39.98
# rpmMax                                                                  3487
# rpmAverage                                                           1431.29
# gpsSpeedAverage                                                        21.99
# vssMax                                                                 53.44
# vssAverage                                                             23.06
# tcuTemperatureMin                                                      82.40
# tcuTemperatureMax                                                     109.40
# tcuTemperatureAverage                                                 104.87
# coolantMin                                                            158.00
# coolantMax                                                            188.60
# coolantAverage                                                        180.20
# packetStartLocal                                               1508143346000
# tripStartLocal                                                 1508143346000
# milIndicator                                                               F
# monitorsNotReady                                                           0
# imei                                                                60DF5417
# gatewayTs                                                      1515613306592
# diagnosticTroubleCodeData                                                 []
# diagnosticPidData          [[64768, 47, 100], [64768, 1, 517376], [64800,...
# iwrapVer                                                                 NaN
# sourceSystem                                                             NaN
# configVer                                                                NaN
# oemName                                                                  NaN
# unitType                                                                 NaN
# cpVer                                                                    NaN
# igpsVer                                                                  NaN
# messageType                                                              NaN
# pomVer                                                                   NaN
# headerVer                                                                NaN
# timestamp                                                                NaN
# deviceType                                                               NaN
# visorVer                                                                 NaN
# transactionId                                                            NaN
# deviceSerialNo                                                           NaN
# subOrganization                                                          NaN
# organization                                                             NaN
# operation                                                                NaN
#
#                                                          header
# checkEngineLightFlag                                        NaN
# batteryVoltageStableTime                                    NaN
# batteryVoltageStable                                        NaN
# batteryVoltageOff                                           NaN
# batteryCrankParamTN                                         NaN
# batteryCrankParamVN                                         NaN
# batteryCrankParamTP                                         NaN
# batteryCrankParamVP                                         NaN
# batteryCrankParamTT                                         NaN
# batteryCrankParamV0                                         NaN
# batteryVoltageMaxOn                                         NaN
# batteryVoltageMinOn                                         NaN
# batteryVoltageMaxOff                                        NaN
# batteryVoltageMinOff                                        NaN
# batteryVoltageOnAverage                                     NaN
# engineLoadMax                                               NaN
# engineLoadAverage                                           NaN
# rpmMax                                                      NaN
# rpmAverage                                                  NaN
# gpsSpeedAverage                                             NaN
# vssMax                                                      NaN
# vssAverage                                                  NaN
# tcuTemperatureMin                                           NaN
# tcuTemperatureMax                                           NaN
# tcuTemperatureAverage                                       NaN
# coolantMin                                                  NaN
# coolantMax                                                  NaN
# coolantAverage                                              NaN
# packetStartLocal                                            NaN
# tripStartLocal                                              NaN
# milIndicator                                                NaN
# monitorsNotReady                                            NaN
# imei                                                   60DF5417
# gatewayTs                                                   NaN
# diagnosticTroubleCodeData                                   NaN
# diagnosticPidData                                           NaN
# iwrapVer                                                 1.9.20
# sourceSystem                                                CDP
# configVer                                                   1.1
# oemName                                                     HUM
# unitType                                                      0
# cpVer                                                  7.50.1.9
# igpsVer                                                   1.3.7
# messageType                                        Notification
# pomVer                                                      1.0
# headerVer                                                    V6
# timestamp                                                     0
# deviceType                                              InDrive
# visorVer                                                 1.4.35
# transactionId              53098471-7787-4160-94b3-cd69dcc70416
# deviceSerialNo                                         60DF5417
# subOrganization                                             HUM
# organization                                                HUM
# operation                                          Notification

# %%
d1=d["data"]

# %%
del d1["diagnosticTroubleCodeData"]

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/46371  1169317818
# 1     https://github.com/pandas-dev/pandas/pull/46370  1169187301
# 2   https://github.com/pandas-dev/pandas/issues/46369  1169147049
# 3     https://github.com/pandas-dev/pandas/pull/46368  1169139335
# 4     https://github.com/pandas-dev/pandas/pull/46367  1169138831
# 5   https://github.com/pandas-dev/pandas/issues/46366  1169110527
# 6   https://github.com/pandas-dev/pandas/issues/46365  1169045049
# 7   https://github.com/pandas-dev/pandas/issues/46364  1169026714
# 8   https://github.com/pandas-dev/pandas/issues/46363  1168813313
# 9   https://github.com/pandas-dev/pandas/issues/46362  1168619031
# 10    https://github.com/pandas-dev/pandas/pull/46361  1168510691
# 11  https://github.com/pandas-dev/pandas/issues/46360  1168242825
# 12  https://github.com/pandas-dev/pandas/issues/46359  1168239506
# 13    https://github.com/pandas-dev/pandas/pull/46358  1167654488
# 14  https://github.com/pandas-dev/pandas/issues/46357  1167647362
# 15  https://github.com/pandas-dev/pandas/issues/46356  1167641459
# 16    https://github.com/pandas-dev/pandas/pull/46355  1167627284
# 17    https://github.com/pandas-dev/pandas/pull/46354  1167596828
# 18  https://github.com/pandas-dev/pandas/issues/46353  1167498221
# 19  https://github.com/pandas-dev/pandas/issues/46352  1167470919
# 20  https://github.com/pandas-dev/pandas/issues/46351  1167422549
# 21    https://github.com/pandas-dev/pandas/pull/46350  1167422110
# 22    https://github.com/pandas-dev/pandas/pull/46349  1167417912
# 23    https://github.com/pandas-dev/pandas/pull/46348  1167412829
# 24    https://github.com/pandas-dev/pandas/pull/46347  1167404425
# 25    https://github.com/pandas-dev/pandas/pull/46346  1167386303
# 26    https://github.com/pandas-dev/pandas/pull/46343  1167366731
# 27    https://github.com/pandas-dev/pandas/pull/46342  1167331327
# 28    https://github.com/pandas-dev/pandas/pull/46341  1167329989
# 29  https://github.com/pandas-dev/pandas/issues/46339  1167181077
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85Fsl-6   46371
# 1   PR_kwDOAA0YD840cBkA   46370
# 2    I_kwDOAA0YD85Fr8Sp   46369
# 3   PR_kwDOAA0YD840b3h-   46368
# 4   PR_kwDOAA0YD840b3bW   46367
# 5    I_kwDOAA0YD85FrzX_   46366
# 6    I_kwDOAA0YD85FrjY5   46365
# 7    I_kwDOAA0YD85Fre6a   46364
# 8    I_kwDOAA0YD85Fqq0B   46363
# 9    I_kwDOAA0YD85Fp7YX   46362
# 10  PR_kwDOAA0YD840ZxzX   46361
# 11   I_kwDOAA0YD85FofiJ   46360
# 12   I_kwDOAA0YD85FoeuS   46359
# 13  PR_kwDOAA0YD840W_1h   46358
# 14   I_kwDOAA0YD85FmOKC   46357
# 15   I_kwDOAA0YD85FmMtz   46356
# 16  PR_kwDOAA0YD840W6yt   46355
# 17  PR_kwDOAA0YD840W1Lz   46354
# 18   I_kwDOAA0YD85Flpvt   46353
# 19   I_kwDOAA0YD85FljFH   46352
# 20   I_kwDOAA0YD85FlXRV   46351
# 21  PR_kwDOAA0YD840WVgz   46350
# 22  PR_kwDOAA0YD840WUvE   46349
# 23  PR_kwDOAA0YD840WT3e   46348
# 24  PR_kwDOAA0YD840WSZR   46347
# 25  PR_kwDOAA0YD840WO50   46346
# 26  PR_kwDOAA0YD840WLMs   46343
# 27  PR_kwDOAA0YD840WEz_   46342
# 28  PR_kwDOAA0YD840WEmO   46341
# 29   I_kwDOAA0YD85FkcUV   46339
#
#                                                 title  ...  \
# 0        BUG: string series to numpy array conversion  ...
# 1                   TST: Fix warnings & skip -> xfail  ...
# 2   SeriesGroupBy.apply results in wrong name when...  ...
# 3       DOC: Add docs about using numba with parallel  ...
# 4   BUG: Fix remaining cases of groupby(...).trans...  ...
# 5   BUG: where method results in a different outpu...  ...
# 6   DOC: read_csv using pyarrow and a different en...  ...
# 7   DOC: Adding Korean translation version of Pand...  ...
# 8   BUG: Cannot install pandas in docker via setup...  ...
# 9   BUG: The indexes of `DataFrame.describe(percen...  ...
# 10        Fixed `Period` and `PeriodIndex` formatting  ...
# 11       BUG: 32 bit build does not work with -Werror  ...
# 12                DOC: operator methods accept dicts   ...
# 13                   CI: Debug Windows stack overflow  ...
# 14  BUG: value_counts(observed=True) inconsistent ...  ...
# 15  Bug: Dataframe.apply on Empty Dataframe Return...  ...
# 16  ENH: consistency of input args for boundaries ...  ...
# 17            DOC: minor fixes to 1.4.2 release notes  ...
# 18  DOC: Document that astype() for Series and Dat...  ...
# 19  ENH: read_excel should assume engine when pass...  ...
# 20                    Question: why use Azure for CI?  ...
# 21      TST: xfail(strict=False) flaky hashtable test  ...
# 22                           PERF: Index[StringArray]  ...
# 23  Series.map Performance Improvement When Using ...  ...
# 24                                 Fix snappy version  ...
# 25                  WIP Use provision-with-micromamba  ...
# 26  TYP: Add typing for pd.to_timedelta, fix Timed...  ...
# 27             Bug fix -  groupby sum removed columns  ...
# 28            PERF: use bisect_right_i8 in vectorized  ...
# 29                                      PyCon US 2022  ...
#
#                   updated_at closed_at author_association  active_lock_reason  \
# 0  2022-03-15 08:01:36+00:00       NaT               NONE                 NaN
# 1  2022-03-15 05:39:19+00:00       NaT             MEMBER                 NaN
# 2  2022-03-15 03:44:16+00:00       NaT             MEMBER                 NaN
# 3  2022-03-15 03:28:34+00:00       NaT             MEMBER                 NaN
# 4  2022-03-15 03:29:41+00:00       NaT             MEMBER                 NaN
# 5  2022-03-15 02:33:06+00:00       NaT               NONE                 NaN
# 6  2022-03-15 00:21:48+00:00       NaT               NONE                 NaN
# 7  2022-03-14 23:51:17+00:00       NaT               NONE                 NaN
# 8  2022-03-14 19:39:46+00:00       NaT               NONE                 NaN
# 9  2022-03-14 19:21:24+00:00       NaT               NONE                 NaN
# 10 2022-03-14 22:01:56+00:00       NaT        CONTRIBUTOR                 NaN
# 11 2022-03-14 11:47:02+00:00       NaT        CONTRIBUTOR                 NaN
# 12 2022-03-14 11:26:06+00:00       NaT               NONE                 NaN
# 13 2022-03-14 22:53:31+00:00       NaT             MEMBER                 NaN
# 14 2022-03-13 19:35:51+00:00       NaT               NONE                 NaN
# 15 2022-03-13 17:21:28+00:00       NaT               NONE                 NaN
# 16 2022-03-14 01:25:38+00:00       NaT        CONTRIBUTOR                 NaN
# 17 2022-03-13 14:30:57+00:00       NaT             MEMBER                 NaN
# 18 2022-03-13 06:52:08+00:00       NaT               NONE                 NaN
# 19 2022-03-14 14:13:03+00:00       NaT               NONE                 NaN
# 20 2022-03-12 23:13:37+00:00       NaT        CONTRIBUTOR                 NaN
# 21 2022-03-15 02:05:14+00:00       NaT             MEMBER                 NaN
# 22 2022-03-12 22:40:13+00:00       NaT             MEMBER                 NaN
# 23 2022-03-14 16:47:30+00:00       NaT               NONE                 NaN
# 24 2022-03-15 00:41:02+00:00       NaT        CONTRIBUTOR                 NaN
# 25 2022-03-14 17:41:55+00:00       NaT        CONTRIBUTOR                 NaN
# 26 2022-03-14 03:10:26+00:00       NaT        CONTRIBUTOR                 NaN
# 27 2022-03-14 14:40:29+00:00       NaT        CONTRIBUTOR                 NaN
# 28 2022-03-14 16:20:35+00:00       NaT             MEMBER                 NaN
# 29 2022-03-12 05:00:28+00:00       NaT             MEMBER                 NaN
#
#                                                  body  \
# 0   ### Pandas version checks\n\n- [X] I have chec...
# 1   - [x] [Tests added and passed](https://pandas....
# 2   ```\r\ndf = pd.DataFrame({'a': [0], 'b': [1]})...
# 3   - [x] All [code checks passed](https://pandas....
# 4   - [x] closes #17093 (Replace xxxx with the Git...
# 5   ### Pandas version checks\n\n- [X] I have chec...
# 6   ### Pandas version checks\n\n- [X] I have chec...
# 7   ### Pandas version checks\r\n\r\n- [X] I have ...
# 8   ### Pandas version checks\r\n\r\n- [X] I have ...
# 9   ### Pandas version checks\n\n- [X] I have chec...
# 10  - [x] closes #46252\r\n- [x] Improved docstrin...
# 11  ### Pandas version checks\r\n\r\n- [X] I have ...
# 12  ### Pandas version checks\n\n- [X] I have chec...
# 13  ```\r\nThread 0x0000142c (most recent call fir...
# 14  ### Pandas version checks\r\n\r\n- [X] I have ...
# 15  Hi,\r\n\r\nNot 100% if this is a bug or the in...
# 16  - [x] closes #40245 \r\n- [ ] [Tests added and...
# 17                                               None
# 18  ### Pandas version checks\n\n- [X] I have chec...
# 19  #### Is your feature request related to a prob...
# 20  What’s the reason that pandas uses GHA alongsi...
# 21  - [x] [Tests added and passed](https://pandas....
# 22  - [x] closes #45652 (Replace xxxx with the Git...
# 23  - [x] closes #46248\r\n- [ ] [Tests added and ...
# 24  Fix for https://github.com/pandas-dev/pandas/p...
# 25  Based on #45701\r\n\r\n- [ ] closes #xxxx (Rep...
# 26  Add typing for pd.to_timedelta\r\nChange opera...
# 27  - [x] closes #44132 \r\n- [ ] [Tests added and...
# 28  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 29  Do we have any plan for PyCon US 2022?\r\n\r\n...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#     performed_via_github_app draft  \
# 0                        NaN   NaN
# 1                        NaN   0.0
# 2                        NaN   NaN
# 3                        NaN   0.0
# 4                        NaN   0.0
# 5                        NaN   NaN
# 6                        NaN   NaN
# 7                        NaN   NaN
# 8                        NaN   NaN
# 9                        NaN   NaN
# 10                       NaN   0.0
# 11                       NaN   NaN
# 12                       NaN   NaN
# 13                       NaN   0.0
# 14                       NaN   NaN
# 15                       NaN   NaN
# 16                       NaN   0.0
# 17                       NaN   0.0
# 18                       NaN   NaN
# 19                       NaN   NaN
# 20                       NaN   NaN
# 21                       NaN   0.0
# 22                       NaN   0.0
# 23                       NaN   0.0
# 24                       NaN   0.0
# 25                       NaN   1.0
# 26                       NaN   0.0
# 27                       NaN   0.0
# 28                       NaN   0.0
# 29                       NaN   NaN
#
#                                          pull_request
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2                                                 NaN
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14                                                NaN
# 15                                                NaN
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
# [30 rows x 29 columns]

# %%
import requests
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46371',
#   'id': 1169317818,
#   'node_id': 'I_kwDOAA0YD85Fsl-6',
#   'number': 46371,
#   'title': 'BUG: string series to numpy array conversion',
#   'user': {'login': 'deepspacesparkle',
#    'id': 97976621,
#    'node_id': 'U_kgDOBdcBLQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97976621?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/deepspacesparkle',
#    'html_url': 'https://github.com/deepspacesparkle',
#    'followers_url': 'https://api.github.com/users/deepspacesparkle/followers',
#    'following_url': 'https://api.github.com/users/deepspacesparkle/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/deepspacesparkle/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/deepspacesparkle/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/deepspacesparkle/subscriptions',
#    'organizations_url': 'https://api.github.com/users/deepspacesparkle/orgs',
#    'repos_url': 'https://api.github.com/users/deepspacesparkle/repos',
#    'events_url': 'https://api.github.com/users/deepspacesparkle/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/deepspacesparkle/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-15T08:01:36Z',
#   'updated_at': '2022-03-15T08:01:36Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\ndf = pd.DataFrame({\'a\':["1","2","3"]}, dtype="string")\r\n\r\ntype(df[\'a\'].values)\r\ntype(df[\'a\'].unique)\n```\n\n\n### Issue Description\n\nI am getting pandas.core.arrays.string_.StringArray when converting pandas string series to NumPy array with unique or values methods. Could be associated with https://github.com/pandas-dev/pandas/issues/46366\n\n### Expected Behavior\n\npandas.values and pandas.unique returns np.ndarray\n\n### Installed Versions\n\n<details>\r\n\r\npandas: 1.3.5, numpy: 1.21.3\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46370',
#   'id': 1169187301,
#   'node_id': 'PR_kwDOAA0YD840cBkA',
#   'number': 46370,
#   'title': 'TST: Fix warnings & skip -> xfail',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 58,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-15T04:59:23Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2022-03-15T04:59:23Z',
#   'updated_at': '2022-03-15T05:39:19Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46370',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46370',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46370.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46370.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46369',
#   'id': 1169147049,
#   'node_id': 'I_kwDOAA0YD85Fr8Sp',
#   'number': 46369,
#   'title': 'SeriesGroupBy.apply results in wrong name when there is a single grouper',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 987,
#    'closed_issues': 837,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2022-03-15T03:43:59Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-03-15T03:43:58Z',
#   'updated_at': '2022-03-15T03:44:16Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "```\r\ndf = pd.DataFrame({'a': [0], 'b': [1]})\r\nser = df['b'].rename(None)\r\nprint(ser.groupby(df['a']).apply(lambda x: x))\r\n\r\ndf = pd.DataFrame({'a': [0, 1], 'b': [1, 2]})\r\nser = df['b'].rename(None)\r\nprint(ser.groupby(df['a']).apply(lambda x: x))\r\n```\r\n\r\nproduces\r\n\r\n```\r\n0    1\r\nName: 0, dtype: int64\r\n0    1\r\n1    2\r\ndtype: int64\r\n```\r\n\r\nIn the first case, the `name` attribute on the resulting Series is set as `0`, the group. In the second case, the two groups have different names and so the correct `name` attribute of `None` is on the result. The `name` attribute should be `None` in the first case as well.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46368',
#   'id': 1169139335,
#   'node_id': 'PR_kwDOAA0YD840b3h-',
#   'number': 46368,
#   'title': 'DOC: Add docs about using numba with parallel',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 58,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-15T04:59:23Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-03-15T03:28:34Z',
#   'updated_at': '2022-03-15T03:28:34Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46368',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46368',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46368.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46368.patch',
#    'merged_at': None},
#   'body': '- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46367',
#   'id': 1169138831,
#   'node_id': 'PR_kwDOAA0YD840b3bW',
#   'number': 46367,
#   'title': 'BUG: Fix remaining cases of groupby(...).transform with dropna=True',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-15T03:27:34Z',
#   'updated_at': '2022-03-15T03:29:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46367',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46367',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46367.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46367.patch',
#    'merged_at': None},
#   'body': '- [x] closes #17093 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46366',
#   'id': 1169110527,
#   'node_id': 'I_kwDOAA0YD85FrzX_',
#   'number': 46366,
#   'title': 'BUG: where method results in a different outputs with "object" and "string" dtypes',
#   'user': {'login': 'Leejung8763',
#    'id': 50440358,
#    'node_id': 'MDQ6VXNlcjUwNDQwMzU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50440358?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Leejung8763',
#    'html_url': 'https://github.com/Leejung8763',
#    'followers_url': 'https://api.github.com/users/Leejung8763/followers',
#    'following_url': 'https://api.github.com/users/Leejung8763/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Leejung8763/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Leejung8763/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Leejung8763/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Leejung8763/orgs',
#    'repos_url': 'https://api.github.com/users/Leejung8763/repos',
#    'events_url': 'https://api.github.com/users/Leejung8763/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Leejung8763/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-15T02:33:06Z',
#   'updated_at': '2022-03-15T02:33:06Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\ndf = pd.DataFrame({\'A\':["1","","3"]}, dtype="object")\r\ndf.where(df!="", np.nan, inplace=True)\r\n\r\ndf = pd.DataFrame({\'A\':["1","","3"]}, dtype="string")\r\ndf.where(df!="", np.nan, inplace=True)\n```\n\n\n### Issue Description\n\nI am getting different results when using the where method with different data type which are "object" and "string".\r\n\n\n### Expected Behavior\n\nFirst, consider the dataframe with "object" and `inplace=True` options.\r\n\r\nThen, I got a result that I expected.\r\n\r\n```\r\ndf = pd.DataFrame({\'A\':["1","","3"]}, dtype="object")\r\ndf.where(df!="", np.nan, inplace=True)\r\n    a\r\n0   1\r\n1   NaN\r\n2   3\r\n```\r\n\r\nBut, when I changed the dtypes "object" to "string", I got different result as below.\r\n\r\n```\r\ndf = pd.DataFrame({\'A\':["1","","3"]}, dtype="string")\r\ndf.where(df!="", np.nan, inplace=True)\r\n    A\r\n0   <NA>\r\n1   \r\n2   <NA>\r\n```\r\n\r\n\n\n### Installed Versions\n\n<details>\r\n\r\npandas version: 1.3.5 , numpy version: 1.19.5\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46365',
#   'id': 1169045049,
#   'node_id': 'I_kwDOAA0YD85FrjY5',
#   'number': 46365,
#   'title': 'DOC: read_csv using pyarrow and a different encoding does not throw an error',
#   'user': {'login': 'johnkangw',
#    'id': 72617548,
#    'node_id': 'MDQ6VXNlcjcyNjE3NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72617548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/johnkangw',
#    'html_url': 'https://github.com/johnkangw',
#    'followers_url': 'https://api.github.com/users/johnkangw/followers',
#    'following_url': 'https://api.github.com/users/johnkangw/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/johnkangw/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/johnkangw/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/johnkangw/subscriptions',
#    'organizations_url': 'https://api.github.com/users/johnkangw/orgs',
#    'repos_url': 'https://api.github.com/users/johnkangw/repos',
#    'events_url': 'https://api.github.com/users/johnkangw/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/johnkangw/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-15T00:21:48Z',
#   'updated_at': '2022-03-15T00:21:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/reference/api/pandas.read_csv.html\n\n### Documentation problem\n\nDocumentation could be improved illustrate that if you select pyarrow as the engine but a different encoding option (like 'cp1252') that it will not work as pyarrow does not support (from what I can tell) that encoding. \n\n### Suggested fix for documentation\n\nThrow an error when executing code with pyarrow selected and a different encoding. Also, indicate that is not possible (selecting pyarrow and a different encoding). ",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46364',
#   'id': 1169026714,
#   'node_id': 'I_kwDOAA0YD85Fre6a',
#   'number': 46364,
#   'title': 'DOC: Adding Korean translation version of Pandas_Cheat_Sheet.pdf',
#   'user': {'login': 'rcrl',
#    'id': 84949310,
#    'node_id': 'MDQ6VXNlcjg0OTQ5MzEw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84949310?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rcrl',
#    'html_url': 'https://github.com/rcrl',
#    'followers_url': 'https://api.github.com/users/rcrl/followers',
#    'following_url': 'https://api.github.com/users/rcrl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rcrl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rcrl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rcrl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rcrl/orgs',
#    'repos_url': 'https://api.github.com/users/rcrl/repos',
#    'events_url': 'https://api.github.com/users/rcrl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rcrl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-14T23:44:50Z',
#   'updated_at': '2022-03-14T23:51:17Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\r\n\r\n\r\n### Location of the documentation\r\n\r\nhttps://github.com/pandas-dev/pandas/tree/main/doc/cheatsheet/Pandas_Cheat_Sheet.pdf\r\n\r\n### Documentation problem\r\n\r\nGreetings,\r\ncouple of days ago, I found that many korean users using pandas are just referring English version of Pandas_Cheat_Sheet or Japanese version of it.\r\n\r\n\r\n### Suggested fix for documentation\r\nCan I add [Korean translation version of Pandas_Cheat_Sheet.pdf](https://github.com/rcrl/Pandas_Cheat_Sheet_KR)? I expect it can help to get starting pandas for them easily.\r\n\r\nIf it's okay, I can create a PR.\r\n\r\nPlease let me know If I violate some rules or If you feel uncomportable.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46363',
#   'id': 1168813313,
#   'node_id': 'I_kwDOAA0YD85Fqq0B',
#   'number': 46363,
#   'title': 'BUG: Cannot install pandas in docker via setup.py with python 3.10',
#   'user': {'login': 'distortedsignal',
#    'id': 2186874,
#    'node_id': 'MDQ6VXNlcjIxODY4NzQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2186874?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/distortedsignal',
#    'html_url': 'https://github.com/distortedsignal',
#    'followers_url': 'https://api.github.com/users/distortedsignal/followers',
#    'following_url': 'https://api.github.com/users/distortedsignal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/distortedsignal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/distortedsignal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/distortedsignal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/distortedsignal/orgs',
#    'repos_url': 'https://api.github.com/users/distortedsignal/repos',
#    'events_url': 'https://api.github.com/users/distortedsignal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/distortedsignal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-03-14T19:29:17Z',
#   'updated_at': '2022-03-14T19:39:46Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\nDockerfile:\r\n```Dockerfile\r\nARG VERSION\r\n\r\nFROM python:$VERSION-buster\r\n\r\nRUN mkdir /workdir\r\n\r\nADD setup.py /workdir\r\n\r\nRUN cd /workdir && python setup.py install\r\n\r\n```\r\n\r\nsetup.py:\r\n```py\r\n#!/usr/bin/env python\r\n\r\nfrom setuptools import setup\r\n\r\nsetup(\r\n    install_requires=[\r\n        \'pandas\'\r\n    ]\r\n)\r\n\r\n```\r\n\r\nRun the following command:\r\n```sh\r\n> docker build --no-cache --build-arg VERSION="3.9.10" . && echo && echo "Done building on 3.9.10" && echo && docker build --no-cache --build-arg VERSION="3.10.2" .\r\n```\r\n\r\nWhen I run the command, I get the following output:\r\n\r\n```\r\n[+] Building 14.1s (9/9) FINISHED\r\n => [internal] load build definition from Dockerfile                                                                             0.0s\r\n => => transferring dockerfile: 172B                                                                                             0.0s\r\n => [internal] load .dockerignore                                                                                                0.0s\r\n => => transferring context: 2B                                                                                                  0.0s\r\n => [internal] load metadata for docker.io/library/python:3.9.10-buster                                                          0.6s\r\n => CACHED [1/4] FROM docker.io/library/python:3.9.10-buster@sha256:794b620641185e126ce2408f31086b61a0c866d1aa66dccdfa6fccf59ac  0.0s\r\n => [internal] load build context                                                                                                0.0s\r\n => => transferring context: 29B                                                                                                 0.0s\r\n => [2/4] RUN mkdir /workdir                                                                                                     0.3s\r\n => [3/4] ADD setup.py /workdir                                                                                                  0.0s\r\n => [4/4] RUN cd /workdir && python setup.py install                                                                            12.3s\r\n => exporting to image                                                                                                           0.9s\r\n => => exporting layers                                                                                                          0.8s\r\n => => writing image sha256:1bc4a382f0ff188e6b2787572668bf2e39a818b3f289b6effe95cc49bee3b4a9                                     0.0s\r\n\r\nDone building on 3.9.10\r\n\r\n[+] Building 5.7s (8/8) FINISHED\r\n => [internal] load build definition from Dockerfile                                                                             0.0s\r\n => => transferring dockerfile: 37B                                                                                              0.0s\r\n => [internal] load .dockerignore                                                                                                0.0s\r\n => => transferring context: 2B                                                                                                  0.0s\r\n => [internal] load metadata for docker.io/library/python:3.10.2-buster                                                          0.5s\r\n => [internal] load build context                                                                                                0.0s\r\n => => transferring context: 29B                                                                                                 ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46362',
#   'id': 1168619031,
#   'node_id': 'I_kwDOAA0YD85Fp7YX',
#   'number': 46362,
#   'title': 'BUG: The indexes of `DataFrame.describe(percentiles=[0.29, 0.57, 0.58])` are incorrect',
#   'user': {'login': 'idanhazan',
#    'id': 19217750,
#    'node_id': 'MDQ6VXNlcjE5MjE3NzUw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19217750?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/idanhazan',
#    'html_url': 'https://github.com/idanhazan',
#    'followers_url': 'https://api.github.com/users/idanhazan/followers',
#    'following_url': 'https://api.github.com/users/idanhazan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/idanhazan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/idanhazan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/idanhazan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/idanhazan/orgs',
#    'repos_url': 'https://api.github.com/users/idanhazan/repos',
#    'events_url': 'https://api.github.com/users/idanhazan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/idanhazan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-14T16:24:30Z',
#   'updated_at': '2022-03-14T19:21:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\npd.DataFrame(data=[1, 2, 3], columns=['value']).describe(percentiles=[0.29, 0.57, 0.58])\r\n\r\n \tvalue\r\ncount \t3.00\r\nmean \t2.00\r\nstd \t1.00\r\nmin \t1.00\r\n29.0% \t1.58\r\n50% \t2.00\r\n57.0% \t2.14\r\n58.0% \t2.16\r\nmax \t3.00\n```\n\n\n### Issue Description\n\nThe indexes ['29.0%', '57.0%', '58.0%'] should be named as ['29%', '57%', '58%'].\n\n### Expected Behavior\n\n```\r\npd.DataFrame(data=[1, 2, 3], columns=['value']).describe(percentiles=[0.29, 0.57, 0.58]).index\r\n\r\n# Output:\r\nIndex(['count', 'mean', 'std', 'min', '29.0%', '50%', '57.0%', '58.0%', 'max'], dtype='object')\r\n\r\n# Expected:\r\nIndex(['count', 'mean', 'std', 'min', '29%', '50%', '57%', '58%', 'max'], dtype='object')\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.9.10.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.13.0-30-generic\r\nVersion          : #33-Ubuntu SMP Fri Feb 4 17:03:31 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_IL\r\nLOCALE           : en_IL.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.2\r\npip              : 22.0.3\r\nsetuptools       : 59.8.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : 4.4.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.8.0\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : 3.0.3\r\nIPython          : 7.32.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfastparquet      : None\r\nfsspec           : 2022.02.0\r\ngcsfs            : None\r\nmatplotlib       : 3.5.1\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2022.02.0\r\nscipy            : 1.8.0\r\nsqlalchemy       : 1.4.31\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46361',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46361/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46361/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46361/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46361',
#   'id': 1168510691,
#   'node_id': 'PR_kwDOAA0YD840ZxzX',
#   'number': 46361,
#   'title': 'Fixed `Period` and `PeriodIndex` formatting',
#   'user': {'login': 'smarie',
#    'id': 3236794,
#    'node_id': 'MDQ6VXNlcjMyMzY3OTQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3236794?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smarie',
#    'html_url': 'https://github.com/smarie',
#    'followers_url': 'https://api.github.com/users/smarie/followers',
#    'following_url': 'https://api.github.com/users/smarie/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/smarie/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/smarie/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/smarie/subscriptions',
#    'organizations_url': 'https://api.github.com/users/smarie/orgs',
#    'repos_url': 'https://api.github.com/users/smarie/repos',
#    'events_url': 'https://api.github.com/users/smarie/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/smarie/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-03-14T15:04:34Z',
#   'updated_at': '2022-03-14T22:01:56Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46361',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46361',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46361.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46361.patch',
#    'merged_at': None},
# ...
#    'repos_url': 'https://api.github.com/users/jonashaag/repos',
#    'events_url': 'https://api.github.com/users/jonashaag/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonashaag/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T20:11:26Z',
#   'updated_at': '2022-03-14T17:41:55Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46346',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46346',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46346.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46346.patch',
#    'merged_at': None},
#   'body': 'Based on #45701\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46343',
#   'id': 1167366731,
#   'node_id': 'PR_kwDOAA0YD840WLMs',
#   'number': 46343,
#   'title': 'TYP: Add typing for pd.to_timedelta, fix Timedelta operator return types',
#   'user': {'login': 'Dr-Irv',
#    'id': 15113894,
#    'node_id': 'MDQ6VXNlcjE1MTEzODk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15113894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dr-Irv',
#    'html_url': 'https://github.com/Dr-Irv',
#    'followers_url': 'https://api.github.com/users/Dr-Irv/followers',
#    'following_url': 'https://api.github.com/users/Dr-Irv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dr-Irv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dr-Irv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dr-Irv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dr-Irv/orgs',
#    'repos_url': 'https://api.github.com/users/Dr-Irv/repos',
#    'events_url': 'https://api.github.com/users/Dr-Irv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dr-Irv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49597148,
#     'node_id': 'MDU6TGFiZWw0OTU5NzE0OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timedelta',
#     'name': 'Timedelta',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Timedelta data type'},
#    {'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T18:43:38Z',
#   'updated_at': '2022-03-14T03:10:26Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46343',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46343',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46343.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46343.patch',
#    'merged_at': None},
#   'body': 'Add typing for pd.to_timedelta\r\nChange operators on `Timedelta` to return `Timedelta` rather than `timedelta`\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46342',
#   'id': 1167331327,
#   'node_id': 'PR_kwDOAA0YD840WEz_',
#   'number': 46342,
#   'title': 'Bug fix -  groupby sum removed columns',
#   'user': {'login': 'weikhor',
#    'id': 36619387,
#    'node_id': 'MDQ6VXNlcjM2NjE5Mzg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36619387?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/weikhor',
#    'html_url': 'https://github.com/weikhor',
#    'followers_url': 'https://api.github.com/users/weikhor/followers',
#    'following_url': 'https://api.github.com/users/weikhor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/weikhor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/weikhor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/weikhor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/weikhor/orgs',
#    'repos_url': 'https://api.github.com/users/weikhor/repos',
#    'events_url': 'https://api.github.com/users/weikhor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/weikhor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-03-12T16:20:35Z',
#   'updated_at': '2022-03-14T14:40:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46342',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46342',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46342.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46342.patch',
#    'merged_at': None},
#   'body': '- [x] closes #44132 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46341',
#   'id': 1167329989,
#   'node_id': 'PR_kwDOAA0YD840WEmO',
#   'number': 46341,
#   'title': 'PERF: use bisect_right_i8 in vectorized',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 58,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-15T04:59:23Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 4,
#   'created_at': '2022-03-12T16:15:36Z',
#   'updated_at': '2022-03-14T16:20:35Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46341',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46341',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46341.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46341.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46339',
#   'id': 1167181077,
#   'node_id': 'I_kwDOAA0YD85FkcUV',
#   'number': 46339,
#   'title': 'PyCon US 2022',
#   'user': {'login': 'fangchenli',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fangchenli',
#    'html_url': 'https://github.com/fangchenli',
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
#    'following_url': 'https://api.github.com/users/fangchenli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fangchenli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fangchenli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fangchenli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fangchenli/orgs',
#    'repos_url': 'https://api.github.com/users/fangchenli/repos',
#    'events_url': 'https://api.github.com/users/fangchenli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fangchenli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2187005593,
#     'node_id': 'MDU6TGFiZWwyMTg3MDA1NTkz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Community',
#     'name': 'Community',
#     'color': '0bbec4',
#     'default': False,
#     'description': 'Community topics (meetings, etc.)'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T05:00:28Z',
#   'updated_at': '2022-03-12T05:00:28Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'Do we have any plan for PyCon US 2022?\r\n\r\n@pandas-dev/pandas-core @pandas-dev/pandas-triage ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/timeline',
#   'performed_via_github_app': None}]

# %%
len(data1)
# Out:
# 30

# %%
data1[0]['user']['id']
# Out:
# 97976621

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 97976621
# 10647082
# 45562402
# 10647082
# 45562402
# 50440358
# 72617548
# 84949310
# 2186874
# 19217750
# 3236794
# 175722
# 66162599
# 10647082
# 44552904
# 19614993
# 36619387
# 13159005
# 10712109
# 83373712
# 175722
# 10647082
# 8078968
# 20880292
# 175722
# 175722
# 15113894
# 36619387
# 8078968
# 7614606

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46371',
#   'id': 1169317818,
#   'node_id': 'I_kwDOAA0YD85Fsl-6',
#   'number': 46371,
#   'title': 'BUG: string series to numpy array conversion',
#   'user': {'login': 'deepspacesparkle',
#    'id': 97976621,
#    'node_id': 'U_kgDOBdcBLQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97976621?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/deepspacesparkle',
#    'html_url': 'https://github.com/deepspacesparkle',
#    'followers_url': 'https://api.github.com/users/deepspacesparkle/followers',
#    'following_url': 'https://api.github.com/users/deepspacesparkle/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/deepspacesparkle/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/deepspacesparkle/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/deepspacesparkle/subscriptions',
#    'organizations_url': 'https://api.github.com/users/deepspacesparkle/orgs',
#    'repos_url': 'https://api.github.com/users/deepspacesparkle/repos',
#    'events_url': 'https://api.github.com/users/deepspacesparkle/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/deepspacesparkle/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-15T08:01:36Z',
#   'updated_at': '2022-03-15T08:01:36Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\ndf = pd.DataFrame({\'a\':["1","2","3"]}, dtype="string")\r\n\r\ntype(df[\'a\'].values)\r\ntype(df[\'a\'].unique)\n```\n\n\n### Issue Description\n\nI am getting pandas.core.arrays.string_.StringArray when converting pandas string series to NumPy array with unique or values methods. Could be associated with https://github.com/pandas-dev/pandas/issues/46366\n\n### Expected Behavior\n\npandas.values and pandas.unique returns np.ndarray\n\n### Installed Versions\n\n<details>\r\n\r\npandas: 1.3.5, numpy: 1.21.3\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46371/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46370',
#   'id': 1169187301,
#   'node_id': 'PR_kwDOAA0YD840cBkA',
#   'number': 46370,
#   'title': 'TST: Fix warnings & skip -> xfail',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 58,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-15T04:59:23Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2022-03-15T04:59:23Z',
#   'updated_at': '2022-03-15T05:39:19Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46370',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46370',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46370.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46370.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46370/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46369',
#   'id': 1169147049,
#   'node_id': 'I_kwDOAA0YD85Fr8Sp',
#   'number': 46369,
#   'title': 'SeriesGroupBy.apply results in wrong name when there is a single grouper',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 987,
#    'closed_issues': 837,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2022-03-15T03:43:59Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-03-15T03:43:58Z',
#   'updated_at': '2022-03-15T03:44:16Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "```\r\ndf = pd.DataFrame({'a': [0], 'b': [1]})\r\nser = df['b'].rename(None)\r\nprint(ser.groupby(df['a']).apply(lambda x: x))\r\n\r\ndf = pd.DataFrame({'a': [0, 1], 'b': [1, 2]})\r\nser = df['b'].rename(None)\r\nprint(ser.groupby(df['a']).apply(lambda x: x))\r\n```\r\n\r\nproduces\r\n\r\n```\r\n0    1\r\nName: 0, dtype: int64\r\n0    1\r\n1    2\r\ndtype: int64\r\n```\r\n\r\nIn the first case, the `name` attribute on the resulting Series is set as `0`, the group. In the second case, the two groups have different names and so the correct `name` attribute of `None` is on the result. The `name` attribute should be `None` in the first case as well.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46369/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46368',
#   'id': 1169139335,
#   'node_id': 'PR_kwDOAA0YD840b3h-',
#   'number': 46368,
#   'title': 'DOC: Add docs about using numba with parallel',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 58,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-15T04:59:23Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-03-15T03:28:34Z',
#   'updated_at': '2022-03-15T03:28:34Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46368',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46368',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46368.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46368.patch',
#    'merged_at': None},
#   'body': '- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46368/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46367',
#   'id': 1169138831,
#   'node_id': 'PR_kwDOAA0YD840b3bW',
#   'number': 46367,
#   'title': 'BUG: Fix remaining cases of groupby(...).transform with dropna=True',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-15T03:27:34Z',
#   'updated_at': '2022-03-15T03:29:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46367',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46367',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46367.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46367.patch',
#    'merged_at': None},
#   'body': '- [x] closes #17093 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46367/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46366',
#   'id': 1169110527,
#   'node_id': 'I_kwDOAA0YD85FrzX_',
#   'number': 46366,
#   'title': 'BUG: where method results in a different outputs with "object" and "string" dtypes',
#   'user': {'login': 'Leejung8763',
#    'id': 50440358,
#    'node_id': 'MDQ6VXNlcjUwNDQwMzU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50440358?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Leejung8763',
#    'html_url': 'https://github.com/Leejung8763',
#    'followers_url': 'https://api.github.com/users/Leejung8763/followers',
#    'following_url': 'https://api.github.com/users/Leejung8763/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Leejung8763/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Leejung8763/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Leejung8763/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Leejung8763/orgs',
#    'repos_url': 'https://api.github.com/users/Leejung8763/repos',
#    'events_url': 'https://api.github.com/users/Leejung8763/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Leejung8763/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-15T02:33:06Z',
#   'updated_at': '2022-03-15T02:33:06Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\ndf = pd.DataFrame({\'A\':["1","","3"]}, dtype="object")\r\ndf.where(df!="", np.nan, inplace=True)\r\n\r\ndf = pd.DataFrame({\'A\':["1","","3"]}, dtype="string")\r\ndf.where(df!="", np.nan, inplace=True)\n```\n\n\n### Issue Description\n\nI am getting different results when using the where method with different data type which are "object" and "string".\r\n\n\n### Expected Behavior\n\nFirst, consider the dataframe with "object" and `inplace=True` options.\r\n\r\nThen, I got a result that I expected.\r\n\r\n```\r\ndf = pd.DataFrame({\'A\':["1","","3"]}, dtype="object")\r\ndf.where(df!="", np.nan, inplace=True)\r\n    a\r\n0   1\r\n1   NaN\r\n2   3\r\n```\r\n\r\nBut, when I changed the dtypes "object" to "string", I got different result as below.\r\n\r\n```\r\ndf = pd.DataFrame({\'A\':["1","","3"]}, dtype="string")\r\ndf.where(df!="", np.nan, inplace=True)\r\n    A\r\n0   <NA>\r\n1   \r\n2   <NA>\r\n```\r\n\r\n\n\n### Installed Versions\n\n<details>\r\n\r\npandas version: 1.3.5 , numpy version: 1.19.5\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46366/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46365',
#   'id': 1169045049,
#   'node_id': 'I_kwDOAA0YD85FrjY5',
#   'number': 46365,
#   'title': 'DOC: read_csv using pyarrow and a different encoding does not throw an error',
#   'user': {'login': 'johnkangw',
#    'id': 72617548,
#    'node_id': 'MDQ6VXNlcjcyNjE3NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72617548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/johnkangw',
#    'html_url': 'https://github.com/johnkangw',
#    'followers_url': 'https://api.github.com/users/johnkangw/followers',
#    'following_url': 'https://api.github.com/users/johnkangw/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/johnkangw/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/johnkangw/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/johnkangw/subscriptions',
#    'organizations_url': 'https://api.github.com/users/johnkangw/orgs',
#    'repos_url': 'https://api.github.com/users/johnkangw/repos',
#    'events_url': 'https://api.github.com/users/johnkangw/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/johnkangw/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-15T00:21:48Z',
#   'updated_at': '2022-03-15T00:21:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/reference/api/pandas.read_csv.html\n\n### Documentation problem\n\nDocumentation could be improved illustrate that if you select pyarrow as the engine but a different encoding option (like 'cp1252') that it will not work as pyarrow does not support (from what I can tell) that encoding. \n\n### Suggested fix for documentation\n\nThrow an error when executing code with pyarrow selected and a different encoding. Also, indicate that is not possible (selecting pyarrow and a different encoding). ",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46365/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46364',
#   'id': 1169026714,
#   'node_id': 'I_kwDOAA0YD85Fre6a',
#   'number': 46364,
#   'title': 'DOC: Adding Korean translation version of Pandas_Cheat_Sheet.pdf',
#   'user': {'login': 'rcrl',
#    'id': 84949310,
#    'node_id': 'MDQ6VXNlcjg0OTQ5MzEw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84949310?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rcrl',
#    'html_url': 'https://github.com/rcrl',
#    'followers_url': 'https://api.github.com/users/rcrl/followers',
#    'following_url': 'https://api.github.com/users/rcrl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rcrl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rcrl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rcrl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rcrl/orgs',
#    'repos_url': 'https://api.github.com/users/rcrl/repos',
#    'events_url': 'https://api.github.com/users/rcrl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rcrl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-14T23:44:50Z',
#   'updated_at': '2022-03-14T23:51:17Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\r\n\r\n\r\n### Location of the documentation\r\n\r\nhttps://github.com/pandas-dev/pandas/tree/main/doc/cheatsheet/Pandas_Cheat_Sheet.pdf\r\n\r\n### Documentation problem\r\n\r\nGreetings,\r\ncouple of days ago, I found that many korean users using pandas are just referring English version of Pandas_Cheat_Sheet or Japanese version of it.\r\n\r\n\r\n### Suggested fix for documentation\r\nCan I add [Korean translation version of Pandas_Cheat_Sheet.pdf](https://github.com/rcrl/Pandas_Cheat_Sheet_KR)? I expect it can help to get starting pandas for them easily.\r\n\r\nIf it's okay, I can create a PR.\r\n\r\nPlease let me know If I violate some rules or If you feel uncomportable.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46364/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46363',
#   'id': 1168813313,
#   'node_id': 'I_kwDOAA0YD85Fqq0B',
#   'number': 46363,
#   'title': 'BUG: Cannot install pandas in docker via setup.py with python 3.10',
#   'user': {'login': 'distortedsignal',
#    'id': 2186874,
#    'node_id': 'MDQ6VXNlcjIxODY4NzQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2186874?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/distortedsignal',
#    'html_url': 'https://github.com/distortedsignal',
#    'followers_url': 'https://api.github.com/users/distortedsignal/followers',
#    'following_url': 'https://api.github.com/users/distortedsignal/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/distortedsignal/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/distortedsignal/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/distortedsignal/subscriptions',
#    'organizations_url': 'https://api.github.com/users/distortedsignal/orgs',
#    'repos_url': 'https://api.github.com/users/distortedsignal/repos',
#    'events_url': 'https://api.github.com/users/distortedsignal/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/distortedsignal/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-03-14T19:29:17Z',
#   'updated_at': '2022-03-14T19:39:46Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\nDockerfile:\r\n```Dockerfile\r\nARG VERSION\r\n\r\nFROM python:$VERSION-buster\r\n\r\nRUN mkdir /workdir\r\n\r\nADD setup.py /workdir\r\n\r\nRUN cd /workdir && python setup.py install\r\n\r\n```\r\n\r\nsetup.py:\r\n```py\r\n#!/usr/bin/env python\r\n\r\nfrom setuptools import setup\r\n\r\nsetup(\r\n    install_requires=[\r\n        \'pandas\'\r\n    ]\r\n)\r\n\r\n```\r\n\r\nRun the following command:\r\n```sh\r\n> docker build --no-cache --build-arg VERSION="3.9.10" . && echo && echo "Done building on 3.9.10" && echo && docker build --no-cache --build-arg VERSION="3.10.2" .\r\n```\r\n\r\nWhen I run the command, I get the following output:\r\n\r\n```\r\n[+] Building 14.1s (9/9) FINISHED\r\n => [internal] load build definition from Dockerfile                                                                             0.0s\r\n => => transferring dockerfile: 172B                                                                                             0.0s\r\n => [internal] load .dockerignore                                                                                                0.0s\r\n => => transferring context: 2B                                                                                                  0.0s\r\n => [internal] load metadata for docker.io/library/python:3.9.10-buster                                                          0.6s\r\n => CACHED [1/4] FROM docker.io/library/python:3.9.10-buster@sha256:794b620641185e126ce2408f31086b61a0c866d1aa66dccdfa6fccf59ac  0.0s\r\n => [internal] load build context                                                                                                0.0s\r\n => => transferring context: 29B                                                                                                 0.0s\r\n => [2/4] RUN mkdir /workdir                                                                                                     0.3s\r\n => [3/4] ADD setup.py /workdir                                                                                                  0.0s\r\n => [4/4] RUN cd /workdir && python setup.py install                                                                            12.3s\r\n => exporting to image                                                                                                           0.9s\r\n => => exporting layers                                                                                                          0.8s\r\n => => writing image sha256:1bc4a382f0ff188e6b2787572668bf2e39a818b3f289b6effe95cc49bee3b4a9                                     0.0s\r\n\r\nDone building on 3.9.10\r\n\r\n[+] Building 5.7s (8/8) FINISHED\r\n => [internal] load build definition from Dockerfile                                                                             0.0s\r\n => => transferring dockerfile: 37B                                                                                              0.0s\r\n => [internal] load .dockerignore                                                                                                0.0s\r\n => => transferring context: 2B                                                                                                  0.0s\r\n => [internal] load metadata for docker.io/library/python:3.10.2-buster                                                          0.5s\r\n => [internal] load build context                                                                                                0.0s\r\n => => transferring context: 29B                                                                                                 ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46363/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46362',
#   'id': 1168619031,
#   'node_id': 'I_kwDOAA0YD85Fp7YX',
#   'number': 46362,
#   'title': 'BUG: The indexes of `DataFrame.describe(percentiles=[0.29, 0.57, 0.58])` are incorrect',
#   'user': {'login': 'idanhazan',
#    'id': 19217750,
#    'node_id': 'MDQ6VXNlcjE5MjE3NzUw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19217750?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/idanhazan',
#    'html_url': 'https://github.com/idanhazan',
#    'followers_url': 'https://api.github.com/users/idanhazan/followers',
#    'following_url': 'https://api.github.com/users/idanhazan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/idanhazan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/idanhazan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/idanhazan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/idanhazan/orgs',
#    'repos_url': 'https://api.github.com/users/idanhazan/repos',
#    'events_url': 'https://api.github.com/users/idanhazan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/idanhazan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-14T16:24:30Z',
#   'updated_at': '2022-03-14T19:21:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\npd.DataFrame(data=[1, 2, 3], columns=['value']).describe(percentiles=[0.29, 0.57, 0.58])\r\n\r\n \tvalue\r\ncount \t3.00\r\nmean \t2.00\r\nstd \t1.00\r\nmin \t1.00\r\n29.0% \t1.58\r\n50% \t2.00\r\n57.0% \t2.14\r\n58.0% \t2.16\r\nmax \t3.00\n```\n\n\n### Issue Description\n\nThe indexes ['29.0%', '57.0%', '58.0%'] should be named as ['29%', '57%', '58%'].\n\n### Expected Behavior\n\n```\r\npd.DataFrame(data=[1, 2, 3], columns=['value']).describe(percentiles=[0.29, 0.57, 0.58]).index\r\n\r\n# Output:\r\nIndex(['count', 'mean', 'std', 'min', '29.0%', '50%', '57.0%', '58.0%', 'max'], dtype='object')\r\n\r\n# Expected:\r\nIndex(['count', 'mean', 'std', 'min', '29%', '50%', '57%', '58%', 'max'], dtype='object')\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.9.10.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.13.0-30-generic\r\nVersion          : #33-Ubuntu SMP Fri Feb 4 17:03:31 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_IL\r\nLOCALE           : en_IL.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.2\r\npip              : 22.0.3\r\nsetuptools       : 59.8.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : 4.4.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.8.0\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : 3.0.3\r\nIPython          : 7.32.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfastparquet      : None\r\nfsspec           : 2022.02.0\r\ngcsfs            : None\r\nmatplotlib       : 3.5.1\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2022.02.0\r\nscipy            : 1.8.0\r\nsqlalchemy       : 1.4.31\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46362/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46361',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46361/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46361/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46361/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46361',
#   'id': 1168510691,
#   'node_id': 'PR_kwDOAA0YD840ZxzX',
#   'number': 46361,
#   'title': 'Fixed `Period` and `PeriodIndex` formatting',
#   'user': {'login': 'smarie',
#    'id': 3236794,
#    'node_id': 'MDQ6VXNlcjMyMzY3OTQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3236794?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/smarie',
#    'html_url': 'https://github.com/smarie',
#    'followers_url': 'https://api.github.com/users/smarie/followers',
#    'following_url': 'https://api.github.com/users/smarie/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/smarie/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/smarie/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/smarie/subscriptions',
#    'organizations_url': 'https://api.github.com/users/smarie/orgs',
#    'repos_url': 'https://api.github.com/users/smarie/repos',
#    'events_url': 'https://api.github.com/users/smarie/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/smarie/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-03-14T15:04:34Z',
#   'updated_at': '2022-03-14T22:01:56Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46361',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46361',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46361.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46361.patch',
#    'merged_at': None},
# ...
#    'repos_url': 'https://api.github.com/users/jonashaag/repos',
#    'events_url': 'https://api.github.com/users/jonashaag/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jonashaag/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T20:11:26Z',
#   'updated_at': '2022-03-14T17:41:55Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46346',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46346',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46346.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46346.patch',
#    'merged_at': None},
#   'body': 'Based on #45701\r\n\r\n- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46346/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46343',
#   'id': 1167366731,
#   'node_id': 'PR_kwDOAA0YD840WLMs',
#   'number': 46343,
#   'title': 'TYP: Add typing for pd.to_timedelta, fix Timedelta operator return types',
#   'user': {'login': 'Dr-Irv',
#    'id': 15113894,
#    'node_id': 'MDQ6VXNlcjE1MTEzODk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15113894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dr-Irv',
#    'html_url': 'https://github.com/Dr-Irv',
#    'followers_url': 'https://api.github.com/users/Dr-Irv/followers',
#    'following_url': 'https://api.github.com/users/Dr-Irv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dr-Irv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dr-Irv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dr-Irv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dr-Irv/orgs',
#    'repos_url': 'https://api.github.com/users/Dr-Irv/repos',
#    'events_url': 'https://api.github.com/users/Dr-Irv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dr-Irv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49597148,
#     'node_id': 'MDU6TGFiZWw0OTU5NzE0OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timedelta',
#     'name': 'Timedelta',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Timedelta data type'},
#    {'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T18:43:38Z',
#   'updated_at': '2022-03-14T03:10:26Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46343',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46343',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46343.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46343.patch',
#    'merged_at': None},
#   'body': 'Add typing for pd.to_timedelta\r\nChange operators on `Timedelta` to return `Timedelta` rather than `timedelta`\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46343/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46342',
#   'id': 1167331327,
#   'node_id': 'PR_kwDOAA0YD840WEz_',
#   'number': 46342,
#   'title': 'Bug fix -  groupby sum removed columns',
#   'user': {'login': 'weikhor',
#    'id': 36619387,
#    'node_id': 'MDQ6VXNlcjM2NjE5Mzg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36619387?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/weikhor',
#    'html_url': 'https://github.com/weikhor',
#    'followers_url': 'https://api.github.com/users/weikhor/followers',
#    'following_url': 'https://api.github.com/users/weikhor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/weikhor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/weikhor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/weikhor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/weikhor/orgs',
#    'repos_url': 'https://api.github.com/users/weikhor/repos',
#    'events_url': 'https://api.github.com/users/weikhor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/weikhor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-03-12T16:20:35Z',
#   'updated_at': '2022-03-14T14:40:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46342',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46342',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46342.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46342.patch',
#    'merged_at': None},
#   'body': '- [x] closes #44132 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46342/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46341',
#   'id': 1167329989,
#   'node_id': 'PR_kwDOAA0YD840WEmO',
#   'number': 46341,
#   'title': 'PERF: use bisect_right_i8 in vectorized',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 58,
#    'closed_issues': 496,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-03-15T04:59:23Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 4,
#   'created_at': '2022-03-12T16:15:36Z',
#   'updated_at': '2022-03-14T16:20:35Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46341',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46341',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46341.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46341.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46341/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46339',
#   'id': 1167181077,
#   'node_id': 'I_kwDOAA0YD85FkcUV',
#   'number': 46339,
#   'title': 'PyCon US 2022',
#   'user': {'login': 'fangchenli',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fangchenli',
#    'html_url': 'https://github.com/fangchenli',
#    'followers_url': 'https://api.github.com/users/fangchenli/followers',
#    'following_url': 'https://api.github.com/users/fangchenli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fangchenli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fangchenli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fangchenli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fangchenli/orgs',
#    'repos_url': 'https://api.github.com/users/fangchenli/repos',
#    'events_url': 'https://api.github.com/users/fangchenli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fangchenli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2187005593,
#     'node_id': 'MDU6TGFiZWwyMTg3MDA1NTkz',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Community',
#     'name': 'Community',
#     'color': '0bbec4',
#     'default': False,
#     'description': 'Community topics (meetings, etc.)'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-12T05:00:28Z',
#   'updated_at': '2022-03-12T05:00:28Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'Do we have any plan for PyCon US 2022?\r\n\r\n@pandas-dev/pandas-core @pandas-dev/pandas-triage ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46339/timeline',
#   'performed_via_github_app': None}]

# %%
df2=pd.DataFrame(data1,columns=['id','url','repository_url','labels_url','user'])

# %%
df2.to_csv("json_res.csv")
