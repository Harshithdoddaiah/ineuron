# %%
import pandas as pd

# %%
df_1=pd.read_excel('IMDB_Movie_Rating.xlsx',sheet_name=1)
df_1
# Out:
#      Movie Rank                           Movie Name  Year of Release  \
# 0             1             The Shawshank Redemption             1994
# 1             2                        The Godfather             1972
# 2             3                      The Dark Knight             2008
# 3             4                The Godfather Part II             1974
# 4             5                         12 Angry Men             1957
# ..          ...                                  ...              ...
# 195          96                               Jagten             2012
# 196          97    M - Eine Stadt sucht einen Mörder             1931
# 197          98                   North by Northwest             1959
# 198          99                              Vertigo             1958
# 199         100  Le fabuleux destin d'Amélie Poulain             2001
#
#      IMDB Rating
# 0            9.2
# 1            9.2
# 2            9.0
# 3            9.0
# 4            8.9
# ...

# %%
df_1.drop_duplicates()
# Out:
#     Movie Rank                           Movie Name  Year of Release  \
# 0            1             The Shawshank Redemption             1994
# 1            2                        The Godfather             1972
# 2            3                      The Dark Knight             2008
# 3            4                The Godfather Part II             1974
# 4            5                         12 Angry Men             1957
# ..         ...                                  ...              ...
# 95          96                               Jagten             2012
# 96          97    M - Eine Stadt sucht einen Mörder             1931
# 97          98                   North by Northwest             1959
# 98          99                              Vertigo             1958
# 99         100  Le fabuleux destin d'Amélie Poulain             2001
#
#     IMDB Rating
# 0           9.2
# 1           9.2
# 2           9.0
# 3           9.0
# 4           8.9
# ..          ...
# ...
